# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %matplotlib notebook

# %%
learnings = np.load('./resdata/learning_curves.npy')

# %%
learnings.shape
# Out:
# (4000, 50)

# %%
nc = 2
km = KMeans(n_clusters=nc, random_state=2)
clusts = km.fit_predict(learnings[-1:, :].T)
print(np.sum(clusts==0), np.sum(clusts==1))
# Out:
# 25 25

# %%
cols = ['orange', 'b']

for i in range(nc):
    _ = plt.plot(learnings[:, i==clusts], color=cols[i])

plt.xscale('log')
plt.yscale('log')

plt.ylim(0, 0.3)
plt.xlim(1, 4000)
# Out:
# <img src="data:image/png;base64,..." width="432">
# /tmp/ipykernel_101703/307033430.py:9: UserWarning: Attempted to set non-positive bottom ylim on a log-scaled axis.
# Invalid limit will be ignored.
#   plt.ylim(0, 0.3)
# (1, 4000)
